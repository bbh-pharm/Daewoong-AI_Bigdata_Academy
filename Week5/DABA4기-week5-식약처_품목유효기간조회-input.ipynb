# %% [markdown]
# ###  품목유효기간조회
# * 품목유효기간조회(메인페이지 → 의약품등 정보 → 품목갱신정보 → 품목유효기간조회) https://nedrug.mfds.go.kr/pbp/CCBBL01

# %%
import pandas as pd

# %%
url = "https://nedrug.mfds.go.kr/pbp/CCBBL01"

# %%
# 전체 URL을 출력해 봅니다.
"https://nedrug.mfds.go.kr/pbp/CCBBL01/getList?totalPages=76&page=2&limit=10&sort=&sortOrder=&searchYn=&itemName=&entpName=%EB%8C%80%EC%9B%85&itemSeq="
# Out:
# 'https://nedrug.mfds.go.kr/pbp/CCBBL01/getList?totalPages=76&page=2&limit=10&sort=&sortOrder=&searchYn=&itemName=&entpName=%EB%8C%80%EC%9B%85&itemSeq='

# %% [markdown]
# ### 검색 값 설정하기
# * 웹사이트에서 검색한 URL 안에 우리의 검색어가 들어가 있습니다.
# * 이렇게 검색어를 URL에 붙여서 넘기는 문구를 쿼리스트링이라고 부릅니다.
# * 이 문자열을 검색어에 맞게 변경해 줍니다.

# %%
# URL 인코딩 - 한글을 URL에 그대로 보낼 수 없기 때문에 인코딩을 합니다.
# 웹사이트에서 검색한 내용이 인코딩 되어 보이는 것과 같은 현상입니다.
#  parse.quote_plus 를 통해 검색어를 인코딩 합니다.
from urllib import parse
search_word = "한올"
search_word_encode = parse.quote_plus(search_word)
search_word_encode
# Out:
# '%ED%95%9C%EC%98%AC'

# %%
# URL을 생성합니다.
page_no = 1

base_url = "https://nedrug.mfds.go.kr/pbp/CCBBL01/getList?"
params = f"totalPages=76&page={page_no}&limit=10&sort=&sortOrder=&searchYn="
params = f"{params}&itemName=&entpName={search_word_encode}&itemSeq="
params
# Out:
# 'totalPages=76&page=1&limit=10&sort=&sortOrder=&searchYn=&itemName=&entpName=%ED%95%9C%EC%98%AC&itemSeq='

# %% [markdown]
# ### base_url 과 검색어가 들어간 파라메터 합치기

# %%
# base_url 과 params 를 합쳐 url을 만듭니다.
url = base_url + params
url
# Out:
# 'https://nedrug.mfds.go.kr/pbp/CCBBL01/getList?totalPages=76&page=1&limit=10&sort=&sortOrder=&searchYn=&itemName=&entpName=%ED%95%9C%EC%98%AC&itemSeq='

# %% [markdown]
# ### read_html 로 웹사이트의 내용 읽어오기
# * html 소스코드 내부에 < table > 로 된 태그가 있을 때만 가능합니다.

# %%
# read_html을 통해 특정 url에 있는 table 태그에 있는 데이터를 가져옵니다.
table = pd.read_html(url, encoding='utf-8')

# %%
table[0]
# Out:
#    순번         업체명                          제품명         허가일      품목유효기간  \
# 0   1  한올바이오파마(주)      하노마린350연질캡슐(밀크시슬열매건조엑스)  2016-06-30  2021-06-29
# 1   2  한올바이오파마(주)                  아클리어겔(아다팔렌)  2007-08-07  2021-06-30
# 2   3  한올바이오파마(주)           헤어그로정1밀리그램(피나스테리드)  2007-10-12  2021-06-30
# 3   4  한올바이오파마(주)      글루코다운정250밀리그램(메트포르민염산염)  2016-07-12  2021-07-11
# 4   5  한올바이오파마(주)     글루코다운정1000밀리그램(메트포르민염산염)  2016-07-12  2021-07-11
# 5   6  한올바이오파마(주)             파인하이민주(히드록소코발라민)  2016-07-15  2021-07-14
# 6   7  한올바이오파마(주)            파인설타민주(푸르설티아민염산염)  2016-07-18  2021-07-17
# 7   8  한올바이오파마(주)               파인징크주(황산아연수화물)  2016-07-18  2021-07-17
# 8   9  한올바이오파마(주)  세트리손주2000밀리그램(세프트리악손나트륨수화물)  2016-09-28  2021-09-27
# 9  10  한올바이오파마(주)  알파본연질캡슐(알파칼시돌)(수출명:아파본연질캡슐)  1990-07-04  2021-09-30
#
#        갱신신청기한   업종 제조 /수입  허가 번호     품목기준코드  전문/일반                   품목분류  \
# 0  2020-12-29  의약품     제조   5068  201604109  일반의약품                 간장질환용제
# 1  2020-12-30  의약품     제조    571  200709171  전문의약품         피부연화제(부식제를 포함)
# 2  2020-12-30  의약품     제조    570  200711309  전문의약품  모발용제(발모, 탈모, 염모, 양모제)
# 3  2021-01-11  의약품     제조   5069  201604290  전문의약품                  당뇨병용제
# 4  2021-01-11  의약품     제조   5070  201604291  전문의약품                  당뇨병용제
# 5  2021-01-14  의약품     제조   5071  201604382  전문의약품              해열.진통.소염제
# 6  2021-01-18  의약품     제조   5073  201604405  전문의약품                비타민 B1제
# 7  2021-01-18  의약품     제조   5072  201604404  전문의약품                  무기질제제
# 8  2021-03-29  의약품     제조   5075  201605693  전문의약품   주로 그람양성, 음성균에 작용하는 것
# 9  2021-03-30  의약품     제조    158  199000383  일반의약품             비타민 A 및 D제
#
#   허가/신고
# 0    신고
# 1    신고
# 2    신고
# 3    허가
# 4    허가
# 5    신고
# 6    신고
# 7    신고
# 8    신고
# 9    신고

# %% [markdown]
# ### 페이지번호, 검색어를 넘기면 데이터를 가져오는 함수 만들기

# %%
# try, except 를 사용해서 오류가 났을 때 오류대신 메시지만 출력하도록 합니다.
#     try:
#     except Exception as e:
#         return e
def get_page_content(page_no, search_word):
    try:
        search_word_encode = parse.quote_plus(search_word)
        base_url = "https://nedrug.mfds.go.kr/pbp/CCBBL01/getList?"
        params = f"totalPages=8&page={page_no}&limit=100&sort=&sortOrder=&searchYn=&itemName=&entpName={search_word_encode}&itemSeq="
        url = base_url + params
        table = pd.read_html(url, encoding='utf-8')[0]
        
        return table
    
    except Exception as e:
        return e

# %%
# 함수 확인하기
get_page_content(3, '대웅')
# Out:
#      순번       업체명                        제품명         허가일      품목유효기간  \
# 0   201  대웅바이오(주)           엑셀리바패취15(리바스티그민)  2018-07-24  2023-07-23
# 1   202  대웅바이오(주)           엑셀리바패취10(리바스티그민)  2018-07-24  2023-07-23
# 2   203  대웅바이오(주)            엑셀리바패취5(리바스티그민)  2018-07-24  2023-07-23
# 3   204  대웅바이오(주)        대웅바이오아스피린장용정100밀리그램  2018-07-30  2023-07-29
# 4   205   (주)대웅제약    챔키스정0.5밀리그램(바레니클린살리실산염)  2018-08-14  2023-08-13
# ..  ...       ...                        ...         ...         ...
# 95  296  대웅바이오(주)      베아텍정10밀리그람(말레인산에날라프릴)  1989-03-24  2024-06-30
# 96  297   (주)대웅제약           베아디핀정(암로디핀니코틴산염)  2007-10-23  2024-06-30
# 97  298  대웅바이오(주)           대웅바이오아테놀롤정50밀리그램  2008-02-26  2024-06-30
# 98  299  대웅바이오(주)  베아디핀에스정(에스암로디핀베실산염2.5수화물)  2008-03-18  2024-06-30
# 99  300   (주)대웅제약              대웅아테놀롤정50밀리그램  1994-03-26  2024-06-30
#
#         갱신신청기한   업종 제조 /수입  허가 번호     품목기준코드  전문/일반  \
# 0   2023-01-25  의약품     제조   5152  201803070  전문의약품
# 1   2023-01-25  의약품     제조   5151  201803069  전문의약품
# 2   2023-01-25  의약품     제조   5150  201803068  전문의약품
# 3   2023-01-30  의약품     제조   5153  201803126  일반의약품
# 4   2023-02-13  의약품     제조   5174  201803323  전문의약품
# ..         ...  ...    ...    ...        ...    ...
# 95  2024-01-02  의약품     제조    156  198900464  전문의약품
# 96  2024-01-02  의약품     제조    560  200711589  전문의약품
# 97  2024-01-02  의약품     제조    607  200802220  전문의약품
# 98  2024-01-02  의약품     제조    547  200802930  전문의약품
# 99  2024-01-02  의약품     제조    155  199400494  전문의약품
#
#                              품목분류 허가/신고
# 0                      기타의 중추신경용약    허가
# 1                      기타의 중추신경용약    허가
# 2                      기타의 중추신경용약    허가
# 3                       기타의 순환계용약    신고
# 4   따로 분류되지 않고 치료를 주목적으로 하지않는 의약품    허가
# ..                            ...   ...
# 95                          혈압강하제    신고
# 96                          혈압강하제    신고
# 97                          혈압강하제    신고
# 98                          혈압강하제    신고
# 99                          혈압강하제    신고
#
# [100 rows x 13 columns]

# %% [markdown]
# ### 반복문을 통해 전체 페이지를 수집
#
# * tqdm은?
#     * 오래 걸리는 작업의 진행 상태를 표시합니다.
#     * https://tqdm.github.io/

# %%
# tqdm 의 trange를 불러옵니다.
from tqdm import trange
import time

# 페이지마다의 목록을 담아줄 리스트 초기화
page_list = []
search_word = "대웅"
# 반복문을 통해 여러 페이지의 목록 수집하기
for page_no in trange(1, 9):
    temp = get_page_content(page_no, search_word)
    page_list.append(temp)
# Out:
# 100%|████████████████████████████████████████████| 8/8 [00:20<00:00,  2.52s/it]

# %% [markdown]
# ### 수집한 데이터 하나의 데이터프레임으로 합치기
#
#
# <img src="https://pandas.pydata.org/docs/_images/merging_concat_basic.png">
#
# * [Merge, join, concatenate and compare documentation](https://pandas.pydata.org/docs/user_guide/merging.html#merge-join-concatenate-and-compare)

# %%
# concat을 통해 데이터프레임 하나로 만들기
df = pd.concat(page_list, ignore_index=True)
df
# Out:
#       순번       업체명                              제품명         허가일      품목유효기간  \
# 0      1   (주)대웅제약                           리센플러스정  2010-06-23  2021-06-22
# 1      2  대웅바이오(주)            베아클로버정750밀리그램(팜시클로비르)  2016-06-24  2021-06-23
# 2      3   (주)대웅제약                페노스탑플라스타(플루르비프로펜)  2002-03-08  2021-06-30
# 3      4   (주)대웅제약                    베아리모정(피나스테리드)  2007-07-20  2021-06-30
# 4      5   (주)대웅제약                             바렌굿겔  2011-12-29  2021-06-30
# ..   ...       ...                              ...         ...         ...
# 750  751  대웅바이오(주)                 대웅화학말레인산시네파짓(원료)  2006-04-11         NaN
# 751  752  대웅바이오(주)                대웅바이오콜린알포세레이트(원료)  2006-05-30         NaN
# 752  753   (주)대웅제약  대웅파록세틴서방정12.5밀리그램(파록세틴염산염)(수출용)  2006-06-14         NaN
# 753  754  대웅바이오(주)                   대웅화학염산탐스로신(원료)  2006-06-13         NaN
# 754  755  대웅바이오(주)                 대웅화학염산티로프라미드(원료)  2006-07-11         NaN
#
#          갱신신청기한   업종 제조 /수입  허가 번호     품목기준코드  전문/일반                   품목분류  \
# 0    2020-12-22  의약품     제조   5008  201004170  전문의약품     따로 분류되지 않는 대사성 의약품
# 1    2020-12-23  의약품     제조   5106  201603857  전문의약품              기타의 화학요법제
# 2    2020-12-30  의약품     제조    531  200200450  일반의약품           진통.진양.수렴.소염제
# 3    2020-12-30  의약품     제조   5035  200708364  전문의약품  모발용제(발모, 탈모, 염모, 양모제)
# 4    2020-12-30  의약품     제조   5044  201112308  일반의약품             기생성 피부질환용제
# ..          ...  ...    ...    ...        ...    ...                    ...
# 750         NaN  의약품     제조     66  200600612  원료의약품               기타의 조제용약
# 751         NaN  의약품     제조   5016  200604340  원료의약품               기타의 조제용약
# 752         NaN  의약품     제조    450  200605367  전문의약품                 정신신경용제
# 753         NaN  의약품     제조     68  200605487  원료의약품               기타의 조제용약
# 754         NaN  의약품     제조     69  200607029  원료의약품               기타의 조제용약
#
#     허가/신고
# 0      허가
# 1      허가
# 2      신고
# 3      신고
# 4      신고
# ..    ...
# 750    신고
# 751    신고
# 752    허가
# 753    신고
# 754    신고
#
# [755 rows x 13 columns]

# %% [markdown]
# ### 파일로 저장하기

# %%
# 저장할 파일명 만들기
file_name = f"{search_word}_품목유효기간.csv"
file_name
# Out:
# '대웅_품목유효기간.csv'

# %%
# to_csv 로 저장하기
df.to_csv(file_name, index=False, encoding='cp949')

# %%
# 잘 저장되었는지 확인하기
pd.read_csv(file_name, encoding='cp949')
# Out:
#       순번       업체명                              제품명         허가일      품목유효기간  \
# 0      1   (주)대웅제약                           리센플러스정  2010-06-23  2021-06-22
# 1      2  대웅바이오(주)            베아클로버정750밀리그램(팜시클로비르)  2016-06-24  2021-06-23
# 2      3   (주)대웅제약                페노스탑플라스타(플루르비프로펜)  2002-03-08  2021-06-30
# 3      4   (주)대웅제약                    베아리모정(피나스테리드)  2007-07-20  2021-06-30
# 4      5   (주)대웅제약                             바렌굿겔  2011-12-29  2021-06-30
# ..   ...       ...                              ...         ...         ...
# 750  751  대웅바이오(주)                 대웅화학말레인산시네파짓(원료)  2006-04-11         NaN
# 751  752  대웅바이오(주)                대웅바이오콜린알포세레이트(원료)  2006-05-30         NaN
# 752  753   (주)대웅제약  대웅파록세틴서방정12.5밀리그램(파록세틴염산염)(수출용)  2006-06-14         NaN
# 753  754  대웅바이오(주)                   대웅화학염산탐스로신(원료)  2006-06-13         NaN
# 754  755  대웅바이오(주)                 대웅화학염산티로프라미드(원료)  2006-07-11         NaN
#
#          갱신신청기한   업종 제조 /수입  허가 번호     품목기준코드  전문/일반                   품목분류  \
# 0    2020-12-22  의약품     제조   5008  201004170  전문의약품     따로 분류되지 않는 대사성 의약품
# 1    2020-12-23  의약품     제조   5106  201603857  전문의약품              기타의 화학요법제
# 2    2020-12-30  의약품     제조    531  200200450  일반의약품           진통.진양.수렴.소염제
# 3    2020-12-30  의약품     제조   5035  200708364  전문의약품  모발용제(발모, 탈모, 염모, 양모제)
# 4    2020-12-30  의약품     제조   5044  201112308  일반의약품             기생성 피부질환용제
# ..          ...  ...    ...    ...        ...    ...                    ...
# 750         NaN  의약품     제조     66  200600612  원료의약품               기타의 조제용약
# 751         NaN  의약품     제조   5016  200604340  원료의약품               기타의 조제용약
# 752         NaN  의약품     제조    450  200605367  전문의약품                 정신신경용제
# 753         NaN  의약품     제조     68  200605487  원료의약품               기타의 조제용약
# 754         NaN  의약품     제조     69  200607029  원료의약품               기타의 조제용약
#
#     허가/신고
# 0      허가
# 1      허가
# 2      신고
# 3      신고
# 4      신고
# ..    ...
# 750    신고
# 751    신고
# 752    허가
# 753    신고
# 754    신고
#
# [755 rows x 13 columns]
